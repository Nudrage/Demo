# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Q1

# %%
years_list = []
born_yr = 2002
for i in range(6):
    years_list.append(born_yr + i)
print("Years list :",years_list)
# Out:
# Years list : [2002, 2003, 2004, 2005, 2006, 2007]

# %% [markdown]
# # Q2

# %%
third_b_day = years_list[3]
print("Third Birthday will fall in :", third_b_day)
# Out:
# Third Birthday will fall in : 2005

# %% [markdown]
# # Q3

# %%
print("The year in which I was oldest is :",years_list[-1])
# Out:
# The year in which I was oldest is : 2007

# %% [markdown]
# # Q4

# %%
things = ["mozzarella", "cinderella", "salmonella"]
print("The list will contains :",things)
# Out:
# The list will contains : ['mozzarella', 'cinderella', 'salmonella']

# %% [markdown]
# # Q5

# %%
things[1] = things[1].capitalize()
print("List after Capitalising the person name :", things)
# Out:
# List after Capitalising the person name : ['mozzarella', 'Cinderella', 'salmonella']

# %% [markdown]
# # Q6

# %%
surprise = ["Grouchu", "Chico", "Harpo"]
print("The surprise list is :", surprise)
# Out:
# The surprise list is : ['Grouchu', 'Chico', 'Harpo']

# %% [markdown]
# # Q7
